# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# uyarıları görmezden gelmeyi seçtik
import warnings 
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
train = pd.read_csv('house-prices-advanced-regression-techniques/train.csv')
x_test = pd.read_csv('house-prices-advanced-regression-techniques/test.csv')
y_test = pd.read_csv('house-prices-advanced-regression-techniques/sample_submission.csv')

# %%
# dosyaları birleştirdik 
test = pd.merge(x_test, y_test, on='Id')
all_data = pd.concat([train, test], axis=0)

# %% [markdown]
# ## Veriyi Tanıma (Data Understanding)

# %%
all_data.describe()
# Out:
#         MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  2919.000000  2433.000000    2919.000000  2919.000000  2919.000000
# mean     57.137718    69.305795   10168.114080     6.089072     5.564577
# std      42.517628    23.344905    7886.996359     1.409947     1.113131
# min      20.000000    21.000000    1300.000000     1.000000     1.000000
# 25%      20.000000    59.000000    7478.000000     5.000000     5.000000
# 50%      50.000000    68.000000    9453.000000     6.000000     5.000000
# 75%      70.000000    80.000000   11570.000000     7.000000     6.000000
# max     190.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  ...  \
# count  2919.000000   2919.000000  2896.000000  2918.000000  2918.000000  ...
# mean   1971.312778   1984.264474   102.201312   441.423235    49.582248  ...
# std      30.291442     20.894344   179.334253   455.610826   169.205611  ...
# ...

# %%
_, bins, _ = plt.hist(all_data.MSSubClass, bins=10, density=1, alpha=0.5, ec='black')

mu, sigma = stats.norm.fit(all_data.MSSubClass)

best_fit_line = stats.norm.pdf(bins, mu, sigma)

plt.plot(bins, best_fit_line, 'g-o')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %% [markdown]
# ## Veri Ön İşleme (Data Preparation)

# %%
# başta biraz indexler karıştığı için burada onları düzeltik
keys = np.arange(0, len(all_data))
all_data.set_index(keys=keys, inplace=True)

# burada da id kolonunu siliyoruz çünkü artık gerek yok
all_data.drop('Id', axis=1, inplace=True)

all_data
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0             60       RL         65.0     8450   Pave   NaN      Reg
# 1             20       RL         80.0     9600   Pave   NaN      Reg
# 2             60       RL         68.0    11250   Pave   NaN      IR1
# 3             70       RL         60.0     9550   Pave   NaN      IR1
# 4             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 2914         160       RM         21.0     1936   Pave   NaN      Reg
# 2915         160       RM         21.0     1894   Pave   NaN      Reg
# 2916          20       RL        160.0    20000   Pave   NaN      Reg
# 2917          85       RL         62.0    10441   Pave   NaN      Reg
# 2918          60       RL         74.0     9627   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# ...
